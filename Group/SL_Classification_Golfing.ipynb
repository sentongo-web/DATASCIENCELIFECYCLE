# %%
# Import libraries
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib as mat
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
# create dataframework for the dataset
golf_df = pd.read_csv("Golf_Gaming.csv")
golf_df
# Out:
#     Day   Outlook Temperature Humidity    Wind Play Golf
# 0    D1     Sunny         Hot     High    Weak        No
# 1    D2     Sunny         Hot     High  Strong        No
# 2    D3  Overcast         Hot     High    Weak       Yes
# 3    D4      Rain        Mild     High    Weak       Yes
# 4    D5      Rain        Cool   Normal    Weak       Yes
# 5    D6      Rain        Cool   Normal  Strong        No
# 6    D7  Overcast        Cool   Normal  Strong       Yes
# 7    D8     Sunny        Mild     High    Weak        No
# 8    D9     Sunny        Cool   Normal    Weak       Yes
# 9   D10      Rain        Mild   Normal    Weak       Yes
# 10  D11     Sunny        Mild   Normal  Strong       Yes
# 11  D12  Overcast        Mild     High  Strong       Yes
# 12  D13  Overcast         Hot   Normal    Weak       Yes
# 13  D14      Rain        Mild     High  Strong        No
# 14  D15     Sunny         Hot      Low    Weak        No
# 15  D16      Rain        Cool      Low  Strong       Yes
# 16  D17  Overcast         Hot      Low    Weak         ?

# %% [markdown]
# ### Exploring the data framework with describe() method to help us understand the dataset more

# %%
golf_df.describe()
# Out:
#          Outlook  Temperature   Humidity       Wind
# count  16.000000    16.000000  16.000000  16.000000
# mean    1.000000     1.000000   1.312500   0.437500
# std     0.894427     0.816497   0.704154   0.512348
# min     0.000000     0.000000   0.000000   0.000000
# 25%     0.000000     0.000000   1.000000   0.000000
# 50%     1.000000     1.000000   1.000000   0.000000
# 75%     2.000000     2.000000   2.000000   1.000000
# max     2.000000     2.000000   2.000000   1.000000

# %% [markdown]
# ###  The Heat Map below shows a matrix where the values in the matrix are represented by colors which helps us to visualize the relationship between multiple variables in a dataset.
# ### The heatmap shows the correlation coefficients between each pair of variables which are measure of the linear relationship between two variables, with values ranging from -1 (perfect negative correlation) to 1 (perfect positive correlation), and 0 indicating no correlation

# %%
#visualising the corelation


# Computing the correlation matrix
corr_matrix = golf_df.corr()

# Printing the correlation matrix
print(corr_matrix)

# Creating a heatmap of the correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
# Out:
#               Outlook  Temperature  Humidity      Wind
# Outlook      1.000000     0.456435 -0.105851  0.145479
# Temperature  0.456435     1.000000 -0.347863  0.318728
# Humidity    -0.105851    -0.347863  1.000000 -0.034648
# Wind         0.145479     0.318728 -0.034648  1.000000
# <AxesSubplot: >

# %% [markdown]
# ## To convert the values in the "Day" column to continuous data rather than categorical data, we did the following;
# 1 . Remove the first character from all values in the "Day" column so since the following characters are numeric thereby making all the values continuous

# %%
# make Day Column continuous by removing first character
golf_df['Day'] = golf_df['Day'].str[1:]
golf_df
# Out:
#    Day   Outlook Temperature Humidity    Wind Play Golf
# 0    1     Sunny         Hot     High    Weak        No
# 1    2     Sunny         Hot     High  Strong        No
# 2    3  Overcast         Hot     High    Weak       Yes
# 3    4      Rain        Mild     High    Weak       Yes
# 4    5      Rain        Cool   Normal    Weak       Yes
# 5    6      Rain        Cool   Normal  Strong        No
# 6    7  Overcast        Cool   Normal  Strong       Yes
# 7    8     Sunny        Mild     High    Weak        No
# 8    9     Sunny        Cool   Normal    Weak       Yes
# 9   10      Rain        Mild   Normal    Weak       Yes
# 10  11     Sunny        Mild   Normal  Strong       Yes
# 11  12  Overcast        Mild     High  Strong       Yes
# 12  13  Overcast         Hot   Normal    Weak       Yes
# 13  14      Rain        Mild     High  Strong        No
# 14  15     Sunny         Hot      Low    Weak        No
# 15  16      Rain        Cool      Low  Strong       Yes
# 16  17  Overcast         Hot      Low    Weak         ?

# %%
# Check unique values in Humidity column
golf_df["Humidity"].unique()
# Out:
# array(['High', 'Normal', 'Low'], dtype=object)

# %%
# Make Wind Column contiunous data  
golf_df["Humidity"].replace(["Low", "Normal", "High"], [0, 1, 2], inplace=True)
golf_df
# Out:
#    Day   Outlook Temperature  Humidity    Wind Play Golf
# 0    1     Sunny         Hot         2    Weak        No
# 1    2     Sunny         Hot         2  Strong        No
# 2    3  Overcast         Hot         2    Weak       Yes
# 3    4      Rain        Mild         2    Weak       Yes
# 4    5      Rain        Cool         1    Weak       Yes
# 5    6      Rain        Cool         1  Strong        No
# 6    7  Overcast        Cool         1  Strong       Yes
# 7    8     Sunny        Mild         2    Weak        No
# 8    9     Sunny        Cool         1    Weak       Yes
# 9   10      Rain        Mild         1    Weak       Yes
# 10  11     Sunny        Mild         1  Strong       Yes
# 11  12  Overcast        Mild         2  Strong       Yes
# 12  13  Overcast         Hot         1    Weak       Yes
# 13  14      Rain        Mild         2  Strong        No
# 14  15     Sunny         Hot         0    Weak        No
# 15  16      Rain        Cool         0  Strong       Yes
# 16  17  Overcast         Hot         0    Weak         ?

# %%
# Check unique values in Wind column
golf_df["Wind"].unique()
# Out:
# array(['Weak', 'Strong'], dtype=object)

# %%
# Make Wind Column contiunous data  
golf_df["Wind"].replace(["Weak", "Strong"], [0, 1], inplace=True)
golf_df
# Out:
#    Day   Outlook Temperature  Humidity  Wind Play Golf
# 0    1     Sunny         Hot         2     0        No
# 1    2     Sunny         Hot         2     1        No
# 2    3  Overcast         Hot         2     0       Yes
# 3    4      Rain        Mild         2     0       Yes
# 4    5      Rain        Cool         1     0       Yes
# 5    6      Rain        Cool         1     1        No
# 6    7  Overcast        Cool         1     1       Yes
# 7    8     Sunny        Mild         2     0        No
# 8    9     Sunny        Cool         1     0       Yes
# 9   10      Rain        Mild         1     0       Yes
# 10  11     Sunny        Mild         1     1       Yes
# 11  12  Overcast        Mild         2     1       Yes
# 12  13  Overcast         Hot         1     0       Yes
# 13  14      Rain        Mild         2     1        No
# 14  15     Sunny         Hot         0     0        No
# 15  16      Rain        Cool         0     1       Yes
# 16  17  Overcast         Hot         0     0         ?

# %%
# Check unique values in Temperature column
golf_df["Temperature"].unique()
# Out:
# array(['Hot', 'Mild', 'Cool'], dtype=object)

# %%
# Make Temperature Column contiunous data  
golf_df["Temperature"].replace(["Hot", "Mild", "Cool"], [0, 1, 2], inplace=True)
golf_df
# Out:
#    Day   Outlook  Temperature  Humidity  Wind Play Golf
# 0    1     Sunny            0         2     0        No
# 1    2     Sunny            0         2     1        No
# 2    3  Overcast            0         2     0       Yes
# 3    4      Rain            1         2     0       Yes
# 4    5      Rain            2         1     0       Yes
# 5    6      Rain            2         1     1        No
# 6    7  Overcast            2         1     1       Yes
# 7    8     Sunny            1         2     0        No
# 8    9     Sunny            2         1     0       Yes
# 9   10      Rain            1         1     0       Yes
# 10  11     Sunny            1         1     1       Yes
# 11  12  Overcast            1         2     1       Yes
# 12  13  Overcast            0         1     0       Yes
# 13  14      Rain            1         2     1        No
# 14  15     Sunny            0         0     0        No
# 15  16      Rain            2         0     1       Yes
# 16  17  Overcast            0         0     0         ?

# %%
# Check unique values in Outlook column
golf_df["Outlook"].unique()
# Out:
# array(['Sunny', 'Overcast', 'Rain'], dtype=object)

# %%
# Make Outlook Column contiunous data  
golf_df["Outlook"].replace(["Sunny", "Overcast", "Rain"], [0, 1, 2], inplace=True)
golf_df
# Out:
#    Day  Outlook  Temperature  Humidity  Wind Play Golf
# 0    1        0            0         2     0        No
# 1    2        0            0         2     1        No
# 2    3        1            0         2     0       Yes
# 3    4        2            1         2     0       Yes
# 4    5        2            2         1     0       Yes
# 5    6        2            2         1     1        No
# 6    7        1            2         1     1       Yes
# 7    8        0            1         2     0        No
# 8    9        0            2         1     0       Yes
# 9   10        2            1         1     0       Yes
# 10  11        0            1         1     1       Yes
# 11  12        1            1         2     1       Yes
# 12  13        1            0         1     0       Yes
# 13  14        2            1         2     1        No
# 14  15        0            0         0     0        No
# 15  16        2            2         0     1       Yes
# 16  17        1            0         0     0         ?

# %%
# Drop last last row since it has null values 
golf_df = golf_df.drop([16])
golf_df
# Out:
#    Day  Outlook  Temperature  Humidity  Wind Play Golf
# 0    1        0            0         2     0        No
# 1    2        0            0         2     1        No
# 2    3        1            0         2     0       Yes
# 3    4        2            1         2     0       Yes
# 4    5        2            2         1     0       Yes
# 5    6        2            2         1     1        No
# 6    7        1            2         1     1       Yes
# 7    8        0            1         2     0        No
# 8    9        0            2         1     0       Yes
# 9   10        2            1         1     0       Yes
# 10  11        0            1         1     1       Yes
# 11  12        1            1         2     1       Yes
# 12  13        1            0         1     0       Yes
# 13  14        2            1         2     1        No
# 14  15        0            0         0     0        No
# 15  16        2            2         0     1       Yes

# %%
# Generate the predictor input

X = golf_df.drop(columns=["Play Golf"])
X
# Out:
#    Day  Outlook  Temperature  Humidity  Wind
# 0    1        0            0         2     0
# 1    2        0            0         2     1
# 2    3        1            0         2     0
# 3    4        2            1         2     0
# 4    5        2            2         1     0
# 5    6        2            2         1     1
# 6    7        1            2         1     1
# 7    8        0            1         2     0
# 8    9        0            2         1     0
# 9   10        2            1         1     0
# 10  11        0            1         1     1
# 11  12        1            1         2     1
# 12  13        1            0         1     0
# 13  14        2            1         2     1
# 14  15        0            0         0     0
# 15  16        2            2         0     1

# %%
# Generate the target output

y = golf_df['Play Golf']
y
# Out:
# 0      No
# 1      No
# 2     Yes
# 3     Yes
# 4     Yes
# 5      No
# 6     Yes
# 7      No
# 8     Yes
# 9     Yes
# 10    Yes
# 11    Yes
# 12    Yes
# 13     No
# 14     No
# 15    Yes
# Name: Play Golf, dtype: object

# %%
# Building the model

from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
# train the model
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# make predictions
prediction = model.predict([[17, 1, 0, 0, 0]])
prediction
# Out:
# array(['Yes'], dtype=object)

# %% [markdown]
# ### Based off the prediction above given the various variables, The value for the last cell is "Yes" Golf will be played on day "17"

# %%
# test model for 20%
#Test model 70-80% of the data
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)

prediction = model.predict(X_test)
 
score = accuracy_score(y_test, prediction)
score
# Out:
# 1.0

# %% [markdown]
# ### The accuracy score for 20% test data and 80% training data is "1.0" meaning that the model is 100% accurate

# %%
# test model for 30%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)

prediction = model.predict(X_test)
 
score = accuracy_score(y_test, prediction)
score
# Out:
# 0.8

# %% [markdown]
# ### The accuracy score for 30% test data and 70% training data is "0.8" meaning that the model is 80% accurate

# %%
# Save model
#Or save as pickle 

import joblib
joblib.dump(model, 'Golf.joblib')
# Out:
# ['Golf.joblib']

# %%
# Generate .dot file
#Decision tree

from sklearn import tree

tree.export_graphviz(model, out_file = 'Play Golf Predictor.dot', 
                     feature_names = ['Day', 'Outlook', 'Temperature', 'Humidity', 'Wind'], 
                     class_names = sorted(y.unique()), label= 'all', 
                     rounded = True, filled= True)

# %%
# Generate tree
tree.plot_tree(model)
# Out:
# [Text(0.5555555555555556, 0.875, 'x[0] <= 13.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.3333333333333333, 0.625, 'x[1] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.2222222222222222, 0.375, 'x[3] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7777777777777778, 0.625, 'x[0] <= 15.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8888888888888888, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]
